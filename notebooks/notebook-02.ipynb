# %%
import spacy

# %%
# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_md")

# %%
text = "Hello World. I'm learning NLP!"

# %%
doc = nlp("Hello World. I'm learning NLP!")

# %%
for token in doc:
    print(token)
# Out:
# Hello
# World
# .
# I
# 'm
# learning
# NLP
# !

# %%
text ="""""
Dr.Smith will see you at 3 p.m. in the ER.
Mr.Ahmed, Dr.Khan, and Ms.Fatima bought an apple, a banana, and an orange from the market.
"""""
